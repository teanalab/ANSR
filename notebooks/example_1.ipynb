# %%
import tensorflow as tf
import gensim
import numpy as np
import pandas as pd

# %%
print("read word2vec pretrained by using gensim:")
filename_word2vec = "../data/GoogleNews-vectors-negative300_unigrams_alphabetic.bin"
model = gensim.models.KeyedVectors.load_word2vec_format(filename_word2vec, binary=True)

print("gensim to numpy embedding matrix:")
vector_dim=300
embedding_matrix = np.zeros((len(model.vocab), vector_dim))
for i in range(len(model.vocab)):
    embedding_vector = model[model.index2word[i]]
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector
print embedding_matrix.shape

print("numpy embedding matrix to embedding tensors:")
saved_embeddings = tf.constant(embedding_matrix)
embedding = tf.Variable(initial_value=saved_embeddings, trainable=False)

print("normalize embeddings:")
norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keepdims=True))
normalized_embeddings = embedding / norm
# Out:
# read word2vec pretrained by using gensim:
# gensim to numpy embedding matrix:
# (869549, 300)
# numpy embedding matrix to embedding tensors:
# normalize embeddings:

# %%
print "find words with no effect:"
for k, v in model.vocab.iteritems():
    if v.count <= 3:
        print k, v.count
# Out:
# find words with no effect:
# VISIONPAD 2
# tricorne 3
# RAFFAELE 1

# %%
# size of network:
n_qw, n_d, n_f, n_fw = 5, 20, 3, 7
doc_words_shape = [n_d, n_f, n_fw]
print "# of query words, # of documents, # of fields, # of field words:", n_qw, n_d, n_f, n_fw
# Out:
# # of query words, # of documents, # of fields, # of field words: 5 20 3 7

# %%
print("define query embedding tensors:")
query_words_tf = tf.Variable(tf.zeros(n_qw, dtype=tf.int32))
query_words_embeddings = tf.nn.embedding_lookup(normalized_embeddings, query_words_tf)
print query_words_embeddings.shape
# Out:
# define query embedding tensors:
# (5, 300)

# %%
print("fielded document words to embedding tensors:")
doc_words_tf = tf.Variable(tf.zeros(doc_words_shape, dtype=tf.int32))
doc_words_embeddings = tf.nn.embedding_lookup(normalized_embeddings, doc_words_tf)
# number of tuplets: 10 -> 10 negative document and 10 positive document so in total 20 documents
old_shape = doc_words_embeddings.shape
print "old_shape:", old_shape
new_shape = [np.prod(old_shape[:3]), old_shape[3]]
doc_words_embeddings = tf.reshape(doc_words_embeddings, new_shape)
print "new_shape:", doc_words_embeddings.shape
# Out:
# fielded document words to embedding tensors:
# old_shape: (20, 3, 7, 300)
# new_shape: (420, 300)

# %%
print "Get Similarity of Words in the Query and all the Documents:"
similarity = tf.matmul(query_words_embeddings, doc_words_embeddings, transpose_b=True)
print similarity.shape
similarity = tf.reshape(similarity, [n_qw, n_d, n_f, n_fw])
print "shape of initial similarity tensor", similarity.shape
# Out:
# Get Similarity of Words in the Query and all the Documents:
# (5, 420)
# shape of initial similarity tensor (5, 20, 3, 7)

# %%
print "Split Similarity Tensor to Docs and Fields:"
# each split corresponds to a field
similarity_splits = map(tf.squeeze, tf.split(similarity, n_f, 2))
print "number of splits (number of documents):", len(similarity_splits)
print "shape of fields for all documents:", map(lambda x: x.shape, similarity_splits)
# Out:
# Split Similarity Tensor to Docs and Fields:
# number of splits (number of documents): 3
# shape of fields for all documents: [TensorShape([Dimension(5), Dimension(20), Dimension(7)]), TensorShape([Dimension(5), Dimension(20), Dimension(7)]), TensorShape([Dimension(5), Dimension(20), Dimension(7)])]

# %%
print "First Fully Connected Layers:"
print similarity_splits[0].shape

att = [tf.Variable(tf.zeros(n_d, dtype=tf.float64)) for _ in range(n_f)]
similarity_fc1 = map(lambda x: tf.transpose(x, perm=(1, 0, 2)), similarity_splits)

for i in range(len(similarity_fc1)):
    att_exp = tf.expand_dims(tf.expand_dims(att[i], 1), 1)
    similarity_fc1[i] = tf.multiply(att_exp, similarity_fc1[i])

print "shape of fields for all documents:", map(lambda x: x.shape, similarity_fc1)
similarity_fc1 = map(lambda x: tf.reshape(x, (n_d, n_qw*n_fw)), similarity_fc1)
print "shape of fields for all documents:", map(lambda x: x.shape, similarity_fc1)
similarity_fc1 = map(lambda x: tf.layers.dense(x, 1), similarity_fc1)
print "shape of fields for all documents:", map(lambda x: x.shape, similarity_fc1)
similarity_fc1 = map(lambda x: tf.tanh(x), similarity_fc1)
print "shape of fields for all documents:", map(lambda x: x.shape, similarity_fc1)
# Out:
# First Fully Connected Layers:
# (5, 20, 7)
# shape of fields for all documents: [TensorShape([Dimension(20), Dimension(5), Dimension(7)]), TensorShape([Dimension(20), Dimension(5), Dimension(7)]), TensorShape([Dimension(20), Dimension(5), Dimension(7)])]
# shape of fields for all documents: [TensorShape([Dimension(20), Dimension(35)]), TensorShape([Dimension(20), Dimension(35)]), TensorShape([Dimension(20), Dimension(35)])]
# shape of fields for all documents: [TensorShape([Dimension(20), Dimension(1)]), TensorShape([Dimension(20), Dimension(1)]), TensorShape([Dimension(20), Dimension(1)])]
# shape of fields for all documents: [TensorShape([Dimension(20), Dimension(1)]), TensorShape([Dimension(20), Dimension(1)]), TensorShape([Dimension(20), Dimension(1)])]

# %%
print "2nd Fully Connected Layers:"
similarity_fc2 = tf.concat(similarity_fc1, axis=1)
print "shape of tensor at the input of fc2:", similarity_fc2.shape
similarity_fc2 = tf.layers.dense(similarity_fc2, 1, kernel_initializer=tf.ones_initializer())
similarity_fc2 = tf.tanh(similarity_fc2)
print "shape of tensor at the output of fc2:", similarity_fc2.shape
similarity_fc2 = tf.squeeze(similarity_fc2)
print "shape of tensor at the output of fc2:", similarity_fc2.shape
# Out:
# First Fully Connected Layers:
# shape of tensor at the input of fc2: (20, 3)
# shape of tensor at the output of fc2: (20, 1)
# shape of tensor at the output of fc2: (20,)

# %%
# read and preprocess files:

print("read the query:")
queries_pd = pd.read_csv("../configs/queries/gov.tsv", names=["qid", "qtext"], delimiter='\t')
print("read the qrels")
qrels_pd = pd.read_csv("../configs/qrels/gov.txt", names=["qid", "nl", "docid", "rel"], delimiter=' ')
print qrels_pd.head(10)
print("read documents:")
txt_len = n_fw
docs_pd = pd.read_csv("../../mfnn-data/govs_mod.csv", names=["docid", "title", "body", "meta"])
docs_pd = docs_pd.replace(np.nan, '', regex=True) 

# query numbers:
qnumbers = queries_pd.qid.values.tolist()

# initialization of dictionaries with keys as query numbers:
query = dict()
query_words_ids = dict()
qrels = dict()
doc_words_ids_d = dict()
docs_d = dict()
docs_pd_d = dict()
docs_att = dict()

for qn in qnumbers:
    print qn, " ",
    
    # extract an specific query
    queries_pd_ = queries_pd[queries_pd.qid==qn]
    query[qn] = queries_pd_["qtext"].values[0].split(' ')
    query[qn] = [x for x in query[qn] if x in model.vocab]
    if n_qw >= len(query[qn]):
        # Padding:
        query[qn] = query[qn] + ["RAFFAELE"] * (n_qw - len(query[qn]))
    else:
        # cutting:
        query[qn] = query[qn][:n_qw]
    query_words_ids[qn] = [model.vocab[x].index for x in query[qn]]

    # extracted qrels for an specific query
    qrels_pd_ = qrels_pd[qrels_pd.qid==qn]
    qrels[qn] = dict(qrels_pd_[["docid", "rel"]].values.tolist())

    # remove documents not in qrels:
    docs_pd_ = docs_pd[docs_pd['docid'].isin(qrels_pd_.docid.values)]
    
    # remove words not in word2vec vocabulary
    docs_pd_.meta = docs_pd_.meta.apply(lambda x: filter(lambda y: (y in model.vocab), x.split()))
    docs_pd_.body = docs_pd_.body.apply(lambda x: filter(lambda y: (y in model.vocab), x.split()))
    docs_pd_.title = docs_pd_.title.apply(lambda x: filter(lambda y: (y in model.vocab), x.split()))

    # attention weights
    att_fun = lambda x: (1.0+txt_len)/(1+len(x))
    docs_att[qn] = [docs_pd_.meta.apply(att_fun).values.tolist()]
    docs_att[qn] += [docs_pd_.body.apply(att_fun).values.tolist()]
    docs_att[qn] += [docs_pd_.title.apply(att_fun).values.tolist()]
        
    # padding
    docs_pd_.meta = docs_pd_.meta.apply(lambda x: x[:txt_len] if len(x)>txt_len else x + ['tricorne']*(txt_len-len(x)))
    docs_pd_.body = docs_pd_.body.apply(lambda x: x[:txt_len] if len(x)>txt_len else x + ['tricorne']*(txt_len-len(x)))
    docs_pd_.title = docs_pd_.title.apply(lambda x: x[:txt_len] if len(x)>txt_len else x + ['tricorne']*(txt_len-len(x)))

    # document fields dictionary
    docs_pd_ = docs_pd_.reset_index(drop=True)
    docs_ids = list(docs_pd_.docid)
    docs = (docs_pd_[["title", "body", "meta"]]).values.tolist()
    docs_d[qn] = dict(zip(docs_ids, docs))

    # merge docs and qrels:
    docs_pd_d[qn] = pd.merge(docs_pd_, qrels_pd_, how='left', on=['docid'])    
    
    # find documents word IDs
    doc_words_ids_d_ = dict()
    for k, doc in docs_d[qn].iteritems():
        doc_words_ids_d_[k] = np.array([[model.vocab[x].index for x in f] for f in doc])
    doc_words_ids_d[qn] = doc_words_ids_d_
    
print
# Out:
# read the query:
# read the qrels
#    qid  nl           docid  rel
# 0  551   0  G14-77-3709129    0
# 1  551   0  G08-22-1623396    0
# 2  551   0  G00-62-3810067    0
# 3  551   0  G03-16-2715908    0
# 4  551   0  G03-04-3678813    0
# 5  551   0  G00-82-0922843    0
# 6  551   0  G14-20-2024537    0
# 7  551   0  G02-47-3151627    0
# 8  551   0  G18-28-0513470    0
# 9  551   0  G22-94-3703003    1
# read documents:
# 551   552   553   554   555   556   557   558   559   560   561   562   563   564   565   566   567   568   569   570   571   572   573   574   575   576   577   578   579   580   581   582   583   584   585   586   587   588   589   590   591   592   593   594   595   596   597   598   599   600

# %%
print "generate tuplets for the hinge loss:"
seq_ids = dict()
seq_names = dict()
seq_rels = dict()
for qn in qnumbers:
    dpos = filter(lambda x: qrels[qn][x] == 1, qrels[qn].keys())
    dneg = filter(lambda x: qrels[qn][x] == 0, qrels[qn].keys())
    pairs = zip(dpos, dneg)
    
    seq_ids_ = []
    seq_names_ = []
    seq_rels_ = []
    for k, v in pairs:
        if k in doc_words_ids_d[qn] and v in doc_words_ids_d[qn]:
            seq_ids_ += [doc_words_ids_d[qn][k]]
            seq_names_ += [k]
            seq_rels_ += [docs_pd_d[qn][docs_pd_d[qn].docid == k].rel.values[0]]
    for k, v in pairs:
        if k in doc_words_ids_d[qn] and v in doc_words_ids_d[qn]:
            seq_ids_ += [doc_words_ids_d[qn][v]]
            seq_names_ += [v]
            seq_rels_ += [docs_pd_d[qn][docs_pd_d[qn].docid == v].rel.values[0]]
    
    # extract from middle to keep the symetrical property of ids 
    n_d_ = len(seq_ids_)
    if n_d_ >= n_d:
        seq_ids[qn] = seq_ids_[(n_d_/2-n_d/2):(n_d_/2+n_d/2)]
        seq_names[qn] = seq_names_[(n_d_/2-n_d/2):(n_d_/2+n_d/2)]
        seq_rels[qn] = seq_rels_[(n_d_/2-n_d/2):(n_d_/2+n_d/2)]
    
qnumbers_ = qnumbers[:]
np.random.shuffle(qnumbers_)
train_qnumbers = qnumbers_[len(qnumbers_)/10:]
test_qnumbers = qnumbers_[:len(qnumbers_)/10]
print train_qnumbers, test_qnumbers

# training data 9/10
training_seq_ids = {k: v for k, v in seq_ids.iteritems() if k in train_qnumbers}
training_seq_names = {k: v for k, v in seq_names.iteritems() if k in train_qnumbers}
training_seq_rels = {k: v for k, v in seq_rels.iteritems() if k in train_qnumbers}

# testing data 1/10
testing_seq_ids = {k: v for k, v in seq_ids.iteritems() if k in test_qnumbers}
testing_seq_names = {k: v for k, v in seq_names.iteritems() if k in test_qnumbers}
testing_seq_rels = {k: v for k, v in seq_rels.iteritems() if k in test_qnumbers}
# Out:
# generate tuplets for the hinge loss:
# [568, 587, 592, 579, 599, 576, 563, 559, 566, 562, 583, 596, 554, 569, 570, 557, 567, 590, 586, 558, 560, 595, 584, 555, 564, 588, 578, 571, 574, 565, 575, 593, 597, 556, 594, 553, 585, 561, 589, 572, 581, 552, 573, 600, 577] [598, 551, 580, 591, 582]

# %%
# hinge loss
margin=0.5
y_pred = similarity_fc2
y_pos, y_neg = map(lambda x: tf.cast(x, dtype=tf.float32), tf.split(y_pred, 2))
loss = tf.maximum(0., margin + y_neg - y_pos)
hinge_loss = tf.reduce_mean(loss)

# %%
# Gradient Descent Optimizer:
train_step = tf.train.GradientDescentOptimizer(0.5).minimize(hinge_loss)

# %%
# test function:
def test():
    for qn in testing_seq_ids.keys():
        _, loss, sim = sess.run([train_step, hinge_loss, similarity_fc2], feed_dict={doc_words_tf:testing_seq_ids[qn], 
                                                                             query_words_tf:query_words_ids[qn]})
        ranks = (-np.squeeze(sim)).argsort()
        print "-"*100
        print "query:", ' '.join(query[qn])
        print "-"*10
        print "rank\tscore\tdocument"
        print testing_seq_names[qn]
        for i, r in enumerate(ranks):
            docname = testing_seq_names[qn][r]
            if docs_pd_d[qn][docs_pd_d[qn].docid == docname].rel.values[0] == 1:
                docs_pd_d_ = docs_pd_d[qn][docs_pd_d[qn].docid == docname][["title", "body", "meta"]].values[0]
                print '%d\t%.3f\t%s' % (i, sim[r], ', '.join([' '.join(x) for x in docs_pd_d_]))
        print "-"*10
        print "loss:", loss
        print "-"*100

# %%
# initialize tensors
init = tf.global_variables_initializer()

# create a tensorflow session
with tf.Session() as sess:
    sess.run(init)
    
    # test before training
    test()
    
    # training
    losses = []
    for epoch in range(5):
        for qn in trainingg_seq_ids.keys():
            _, loss, sim = sess.run([train_step, hinge_loss, similarity_fc2], feed_dict={doc_words_tf:training_seq_ids[qn], 
                                                                             query_words_tf:query_words_ids[qn]})
            losses += [loss]
            print epoch, qn, np.mean(losses)
    
    # test after training
    test()
# Out:
# ----------------------------------------------------------------------------------------------------
# query: education Indian reservations RAFFAELE RAFFAELE
# ----------
# rank	score	document
# ['G04-81-0432546', 'G17-03-3343615', 'G01-89-1605282', 'G19-70-2900269', 'G11-44-0571147', 'G19-71-0508626', 'G38-14-3429707', 'G01-29-0109956', 'G28-18-0755298', 'G02-27-0967960', 'G20-65-3639560', 'G00-44-1599468', 'G10-85-0735685', 'G13-20-3368630', 'G03-95-1936748', 'G43-88-4060816', 'G00-68-2377713', 'G00-84-2692556', 'G05-37-0002575', 'G44-77-3997443']
# 0	0.000	code talk tricorne tricorne tricorne tricorne tricorne, american indian rehabilitation research training center affiliated, adobe win tricorne tricorne tricorne tricorne tricorne
# 9	0.000	remarks prepared for delivery by the honorable, department the interior tricorne tricorne tricorne tricorne, microsoft frontpage office the secretary remarks honorable
# 10	0.000	american educations economics tricorne tricorne tricorne tricorne, guide usda programs for american indians alaska, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 11	0.000	tcu about the initiative index tricorne tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne, adobe tricorne tricorne tricorne tricorne tricorne tricorne
# 12	0.000	examining education programs benefiting native american children, examining education programs benefiting native american children, microsoft frontpage tricorne tricorne tricorne tricorne tricorne
# 13	0.000	sec findings tricorne tricorne tricorne tricorne tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 14	0.000	access america tricorne tricorne tricorne tricorne tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne, access america access america reengineering through information
# 15	0.000	improvement educational opportunities for indian children tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 16	0.000	code talk tricorne tricorne tricorne tricorne tricorne, interagency conference on comprehensive planning for indian, adobe win tricorne tricorne tricorne tricorne tricorne
# 17	0.000	interior secretary advocates outstanding indian education tricorne, department the interior tricorne tricorne tricorne tricorne, microsoft frontpage office the secretary secretary advocates
# ----------
# loss: 0.5
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# query: US immigration history demographics RAFFAELE
# ----------
# rank	score	document
# ['G42-09-1657055', 'G05-26-3997998', 'G21-11-2314205', 'G03-28-3686456', 'G41-14-1478051', 'G44-54-2136920', 'G00-00-2040865', 'G44-93-1211882', 'G13-22-2795542', 'G17-67-4121511', 'G34-66-1281253', 'G00-06-1039005', 'G45-43-0760225', 'G00-68-4089689', 'G08-93-0735750', 'G21-38-3249190', 'G30-50-1698987', 'G04-03-2800864', 'G40-93-1974274', 'G43-85-3222141']
# 0	0.001	briefing tricorne tricorne tricorne tricorne tricorne tricorne, testimony karen president executive director the national, microsoft frontpage tricorne tricorne tricorne tricorne tricorne
# 1	0.001	view links tricorne tricorne tricorne tricorne tricorne, site map sunday february social issues programs, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 2	0.001	tricorne tricorne tricorne tricorne tricorne tricorne tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 5	0.000	net sites politics tempe public library tricorne, net sites by the numbers political science, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 7	0.000	prologue records immigration across the border tricorne, national archives records administration prologue page genealogy, mary ryan prologue is the quarterly journal
# 8	0.000	resources for teachers tricorne tricorne tricorne tricorne, resources for teachers students we recommend that, adobe win tricorne tricorne tricorne tricorne tricorne
# 9	0.000	portrait the usa ch tricorne tricorne tricorne, geography history government business education science medicine, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 13	-0.000	age search information tricorne tricorne tricorne tricorne, age search service the census bureau provides, population division laura tricorne tricorne tricorne tricorne
# 16	-0.001	new york state archives naturalization related records, click here navigate home page search this, new york state archives naturalization records aliens
# 19	-0.001	home page tricorne tricorne tricorne tricorne tricorne, the gateway statistics from over federal agencies, federal statistics united states gateway provides easy
# ----------
# loss: 0.49962702
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# query: Foreign terrorist organizations RAFFAELE RAFFAELE
# ----------
# rank	score	document
# ['G27-36-3259580', 'G23-19-1041231', 'G32-08-0507195', 'G22-21-0529834', 'G23-27-1985240', 'G09-71-0676406', 'G12-57-3063099', 'G44-12-1052895', 'G02-38-4087156', 'G42-58-3525269', 'G27-10-3038228', 'G35-87-3039469', 'G04-11-0548124', 'G02-82-3715386', 'G33-37-3783431', 'G35-64-3051909', 'G01-36-3706042', 'G00-32-3057773', 'G32-24-1612564', 'G02-04-0983008']
# 0	0.007	foreign terrorist organizations tricorne tricorne tricorne tricorne, the state department web site below is, terrorists policy state department foreign counterterrorism counterterrorism
# 1	0.005	middle eastern foreign terrorist organizations tricorne tricorne, middle eastern foreign terrorist organizations group description, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 2	0.005	tricorne tricorne tricorne tricorne tricorne tricorne tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 3	0.004	powell identifies foreign terrorist organizations tricorne tricorne, washington file powell identifies foreign terrorist organizations, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 4	0.004	tricorne tricorne tricorne tricorne tricorne tricorne tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 5	0.003	october tricorne tricorne tricorne tricorne tricorne tricorne, print friendly version report on foreign terrorist, mon jan gmt tricorne tricorne tricorne tricorne
# 8	0.002	department state washington file text powell names, text powell names two groups as foreign, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 9	0.000	k appendix b background information on terrorist, print friendly version appendix b background information, mon jan gmt tricorne tricorne tricorne tricorne
# 11	-0.001	fact sheet state department identifies foreign terrorist, washington file fact sheet state department identifies, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 17	-0.004	tricorne tricorne tricorne tricorne tricorne tricorne tricorne, california national guard international programs home purpose, microsoft frontpage l default tricorne tricorne tricorne
# ----------
# loss: 0.49556193
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# query: intellectual property RAFFAELE RAFFAELE RAFFAELE
# ----------
# rank	score	document
# ['G37-06-3325628', 'G16-46-0232450', 'G01-65-0142653', 'G04-87-2877981', 'G44-68-4097332', 'G02-55-3134570', 'G26-03-2591182', 'G25-88-4165498', 'G15-05-2150481', 'G22-94-3703003', 'G03-73-1026843', 'G14-59-0807875', 'G02-09-3570681', 'G15-83-3965981', 'G31-19-3607797', 'G00-68-2200781', 'G15-66-3795795', 'G26-00-1785848', 'G00-43-1754673', 'G03-88-2255698']
# 0	0.007	computer crime intellectual property section tricorne tricorne, computer crime intellectual property section department justice, melvin murray computer crime intellectual property section
# 1	0.004	view links tricorne tricorne tricorne tricorne tricorne, site map sunday february reference copyright tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 2	0.003	prosecuting intellectual property crimes tricorne tricorne tricorne, email this document computer crime intellectual property, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 4	0.002	orange county public law library tricorne tricorne, orange county public law library home catalog, microsoft frontpage tricorne tricorne tricorne tricorne tricorne
# 9	0.000	tricorne tricorne tricorne tricorne tricorne tricorne tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 10	-0.000	intellectual property information technology tricorne tricorne tricorne, usa facts government politics economy trade laws, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 11	-0.001	ip links tricorne tricorne tricorne tricorne tricorne, statutes regulations pat waiver copyright ip clauses, u netscape dan park tricorne tricorne tricorne
# 13	-0.003	patent trademark copyright intellectual propert tricorne tricorne, patent trademark copyright intellectual property laws usc, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 15	-0.003	research library legal information tricorne tricorne tricorne, information by subject legal information intellectual property, legal information legal intellectual property disability patent
# 17	-0.007	tricorne tricorne tricorne tricorne tricorne tricorne tricorne, federal prosecution violations intellectual property rights copyrights, ed for windows mark burton tricorne tricorne
# ----------
# loss: 0.496998
# ----------------------------------------------------------------------------------------------------
# 0 552 0.48669353
# 0 554 0.48729116
# 0 557 0.48864904
# 0 558 0.48620066
# 0 559 0.48770705
# 0 560 0.48381272
# 0 561 0.48039463
# 0 563 0.47760636
# 0 564 0.47458902
# 0 565 0.46859735
# 0 566 0.46701148
# 0 567 0.46083054
# 0 568 0.45314118
# 0 569 0.43582016
# 0 570 0.42305544
# 0 572 0.40510926
# 0 574 0.38876984
# 0 575 0.37313548
# 0 576 0.35758448
# 0 578 0.34482127
# 0 583 0.32840124
# 0 584 0.3134739
# 0 586 0.30065796
# 0 589 0.28966454
# 0 593 0.27807796
# 0 594 0.26738265
# 0 595 0.25747958
# 0 596 0.249743
# 0 597 0.24113117
# 0 599 0.23309347
# 0 600 0.22557433
# 1 552 0.21852511
# 1 554 0.21190314
# 1 557 0.2056707
# 1 558 0.19979438
# 1 559 0.19424455
# 1 560 0.18899469
# 1 561 0.18402115
# 1 563 0.17930266
# 1 564 0.1748201
# 1 565 0.17055619
# 1 566 0.1667822
# 1 567 0.16290355
# 1 568 0.15920119
# 1 569 0.155974
# 1 570 0.15258327
# 1 572 0.14939284
# 1 574 0.14628051
# 1 575 0.14329518
# 1 576 0.14042929
# 1 578 0.13833922
# 1 583 0.13567886
# 1 584 0.13311887
# 1 586 0.13065371
# 1 589 0.12849462
# 1 593 0.12620007
# 1 594 0.12398603
# 1 595 0.12184834
# 1 596 0.1200276
# 1 597 0.118027136
# 1 599 0.116092265
# 1 600 0.114219815
# 2 552 0.1124068
# 2 554 0.11065045
# 2 557 0.108948134
# 2 558 0.107297406
# 2 559 0.105695955
# 2 560 0.1041416
# 2 561 0.1026323
# 2 563 0.10116613
# 2 564 0.09974125
# 2 565 0.09835596
# 2 566 0.097008616
# 2 567 0.095697686
# 2 568 0.094421715
# 2 569 0.09326805
# 2 570 0.09205677
# 2 572 0.090876564
# 2 574 0.089726225
# 2 575 0.08860465
# 2 576 0.087510765
# 2 578 0.08662159
# 2 583 0.08557796
# 2 584 0.08455917
# 2 586 0.08356436
# 2 589 0.08264572
# 2 593 0.08169577
# 2 594 0.0807674
# 2 595 0.079859905
# 2 596 0.07902642
# 2 597 0.078158
# 2 599 0.07730846
# 2 600 0.076477185
# 3 552 0.0756636
# 3 554 0.07486714
# 3 557 0.07408727
# 3 558 0.07332349
# 3 559 0.072575286
# 3 560 0.0718422
# 3 561 0.07112378
# 3 563 0.07041959
# 3 564 0.069729194
# 3 565 0.06905221
# 3 566 0.06838825
# 3 567 0.06773693
# 3 568 0.06709791
# 3 569 0.066470824
# 3 570 0.065855354
# 3 572 0.06525118
# 3 574 0.064657986
# 3 575 0.06407548
# 3 576 0.06350338
# 3 578 0.062942855
# 3 583 0.062390726
# 3 584 0.061848197
# 3 586 0.061315022
# 3 589 0.060790963
# 3 593 0.060275786
# 3 594 0.059769265
# 3 595 0.059271194
# 3 596 0.058782563
# 3 597 0.058300737
# 3 599 0.057826746
# 3 600 0.057360403
# 4 552 0.05690152
# 4 554 0.05644992
# 4 557 0.056005433
# 4 558 0.055567883
# 4 559 0.055137124
# 4 560 0.054712992
# 4 561 0.054295335
# 4 563 0.053884007
# 4 564 0.053478863
# 4 565 0.05307977
# 4 566 0.052686587
# 4 567 0.052299183
# 4 568 0.051917437
# 4 569 0.051541224
# 4 570 0.051170424
# 4 572 0.05080492
# 4 574 0.050444603
# 4 575 0.05008936
# 4 576 0.049739085
# 4 578 0.049393672
# 4 583 0.04905303
# 4 584 0.048717048
# 4 586 0.04838564
# 4 589 0.04805871
# 4 593 0.047736168
# 4 594 0.047417928
# 4 595 0.0471039
# 4 596 0.04679401
# 4 597 0.046488162
# 4 599 0.04618629
# 4 600 0.045888316
# ----------------------------------------------------------------------------------------------------
# query: education Indian reservations RAFFAELE RAFFAELE
# ----------
# rank	score	document
# ['G04-81-0432546', 'G17-03-3343615', 'G01-89-1605282', 'G19-70-2900269', 'G11-44-0571147', 'G19-71-0508626', 'G38-14-3429707', 'G01-29-0109956', 'G28-18-0755298', 'G02-27-0967960', 'G20-65-3639560', 'G00-44-1599468', 'G10-85-0735685', 'G13-20-3368630', 'G03-95-1936748', 'G43-88-4060816', 'G00-68-2377713', 'G00-84-2692556', 'G05-37-0002575', 'G44-77-3997443']
# 0	0.885	examining education programs benefiting native american children, examining education programs benefiting native american children, microsoft frontpage tricorne tricorne tricorne tricorne tricorne
# 1	0.815	american educations economics tricorne tricorne tricorne tricorne, guide usda programs for american indians alaska, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 2	0.677	tcu about the initiative index tricorne tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne, adobe tricorne tricorne tricorne tricorne tricorne tricorne
# 3	0.661	remarks prepared for delivery by the honorable, department the interior tricorne tricorne tricorne tricorne, microsoft frontpage office the secretary remarks honorable
# 4	0.660	code talk tricorne tricorne tricorne tricorne tricorne, american indian rehabilitation research training center affiliated, adobe win tricorne tricorne tricorne tricorne tricorne
# 5	0.644	interior secretary advocates outstanding indian education tricorne, department the interior tricorne tricorne tricorne tricorne, microsoft frontpage office the secretary secretary advocates
# 6	0.607	sec findings tricorne tricorne tricorne tricorne tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 7	0.577	improvement educational opportunities for indian children tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 8	0.540	access america tricorne tricorne tricorne tricorne tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne, access america access america reengineering through information
# 9	0.491	code talk tricorne tricorne tricorne tricorne tricorne, interagency conference on comprehensive planning for indian, adobe win tricorne tricorne tricorne tricorne tricorne
# ----------
# loss: 0.0
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# query: US immigration history demographics RAFFAELE
# ----------
# rank	score	document
# ['G42-09-1657055', 'G05-26-3997998', 'G21-11-2314205', 'G03-28-3686456', 'G41-14-1478051', 'G44-54-2136920', 'G00-00-2040865', 'G44-93-1211882', 'G13-22-2795542', 'G17-67-4121511', 'G34-66-1281253', 'G00-06-1039005', 'G45-43-0760225', 'G00-68-4089689', 'G08-93-0735750', 'G21-38-3249190', 'G30-50-1698987', 'G04-03-2800864', 'G40-93-1974274', 'G43-85-3222141']
# 0	0.719	view links tricorne tricorne tricorne tricorne tricorne, site map sunday february social issues programs, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 1	0.681	prologue records immigration across the border tricorne, national archives records administration prologue page genealogy, mary ryan prologue is the quarterly journal
# 2	0.668	portrait the usa ch tricorne tricorne tricorne, geography history government business education science medicine, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 3	0.652	briefing tricorne tricorne tricorne tricorne tricorne tricorne, testimony karen president executive director the national, microsoft frontpage tricorne tricorne tricorne tricorne tricorne
# 4	0.650	net sites politics tempe public library tricorne, net sites by the numbers political science, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 5	0.643	tricorne tricorne tricorne tricorne tricorne tricorne tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 6	0.609	home page tricorne tricorne tricorne tricorne tricorne, the gateway statistics from over federal agencies, federal statistics united states gateway provides easy
# 7	0.579	new york state archives naturalization related records, click here navigate home page search this, new york state archives naturalization records aliens
# 8	0.537	age search information tricorne tricorne tricorne tricorne, age search service the census bureau provides, population division laura tricorne tricorne tricorne tricorne
# 9	0.521	resources for teachers tricorne tricorne tricorne tricorne, resources for teachers students we recommend that, adobe win tricorne tricorne tricorne tricorne tricorne
# ----------
# loss: 0.0
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# query: Foreign terrorist organizations RAFFAELE RAFFAELE
# ----------
# rank	score	document
# ['G27-36-3259580', 'G23-19-1041231', 'G32-08-0507195', 'G22-21-0529834', 'G23-27-1985240', 'G09-71-0676406', 'G12-57-3063099', 'G44-12-1052895', 'G02-38-4087156', 'G42-58-3525269', 'G27-10-3038228', 'G35-87-3039469', 'G04-11-0548124', 'G02-82-3715386', 'G33-37-3783431', 'G35-64-3051909', 'G01-36-3706042', 'G00-32-3057773', 'G32-24-1612564', 'G02-04-0983008']
# 0	0.868	middle eastern foreign terrorist organizations tricorne tricorne, middle eastern foreign terrorist organizations group description, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 1	0.848	powell identifies foreign terrorist organizations tricorne tricorne, washington file powell identifies foreign terrorist organizations, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 2	0.725	tricorne tricorne tricorne tricorne tricorne tricorne tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 3	0.721	foreign terrorist organizations tricorne tricorne tricorne tricorne, the state department web site below is, terrorists policy state department foreign counterterrorism counterterrorism
# 4	0.720	october tricorne tricorne tricorne tricorne tricorne tricorne, print friendly version report on foreign terrorist, mon jan gmt tricorne tricorne tricorne tricorne
# 5	0.703	tricorne tricorne tricorne tricorne tricorne tricorne tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 6	0.585	fact sheet state department identifies foreign terrorist, washington file fact sheet state department identifies, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 7	0.551	k appendix b background information on terrorist, print friendly version appendix b background information, mon jan gmt tricorne tricorne tricorne tricorne
# 8	0.536	department state washington file text powell names, text powell names two groups as foreign, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 9	0.482	tricorne tricorne tricorne tricorne tricorne tricorne tricorne, california national guard international programs home purpose, microsoft frontpage l default tricorne tricorne tricorne
# ----------
# loss: 0.0
# ----------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------
# query: intellectual property RAFFAELE RAFFAELE RAFFAELE
# ----------
# rank	score	document
# ['G37-06-3325628', 'G16-46-0232450', 'G01-65-0142653', 'G04-87-2877981', 'G44-68-4097332', 'G02-55-3134570', 'G26-03-2591182', 'G25-88-4165498', 'G15-05-2150481', 'G22-94-3703003', 'G03-73-1026843', 'G14-59-0807875', 'G02-09-3570681', 'G15-83-3965981', 'G31-19-3607797', 'G00-68-2200781', 'G15-66-3795795', 'G26-00-1785848', 'G00-43-1754673', 'G03-88-2255698']
# 0	0.916	computer crime intellectual property section tricorne tricorne, computer crime intellectual property section department justice, melvin murray computer crime intellectual property section
# 1	0.802	research library legal information tricorne tricorne tricorne, information by subject legal information intellectual property, legal information legal intellectual property disability patent
# 2	0.751	prosecuting intellectual property crimes tricorne tricorne tricorne, email this document computer crime intellectual property, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 3	0.736	patent trademark copyright intellectual propert tricorne tricorne, patent trademark copyright intellectual property laws usc, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 4	0.686	tricorne tricorne tricorne tricorne tricorne tricorne tricorne, federal prosecution violations intellectual property rights copyrights, ed for windows mark burton tricorne tricorne
# 5	0.660	orange county public law library tricorne tricorne, orange county public law library home catalog, microsoft frontpage tricorne tricorne tricorne tricorne tricorne
# 6	0.589	intellectual property information technology tricorne tricorne tricorne, usa facts government politics economy trade laws, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 7	0.566	view links tricorne tricorne tricorne tricorne tricorne, site map sunday february reference copyright tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 8	0.496	tricorne tricorne tricorne tricorne tricorne tricorne tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne, tricorne tricorne tricorne tricorne tricorne tricorne tricorne
# 9	0.468	ip links tricorne tricorne tricorne tricorne tricorne, statutes regulations pat waiver copyright ip clauses, u netscape dan park tricorne tricorne tricorne
# ----------
# loss: 0.0
# ----------------------------------------------------------------------------------------------------
